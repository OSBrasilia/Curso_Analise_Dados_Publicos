# %% [markdown]
# # Análise das Emendas Parlamentares da CLDF em 2017
#
# Com base no dados dsponibilizados no Portal de Dados Abertos do GDF iremos analisar as emendas parlamentares da CLDF em 2017.
#
# Como obter os dados:
# - Ir no site de Dados Abertos do DF, escolher governo, escolher emendas 2017
#
# Arquivos:
# - emendasparlamentares-012017.csv
# - emendasparlamentares-022017.csv

# %% [markdown]
# # ATENÇÃO!
# ESSE ARQUIVO TEM UMA ESTRUTURA BIZARRA!
#
# NO MEIO DO ARQUIVO CSV O NÚMERO DE COLUNAS MUDA, COMO SE O ARQUIVO TIVESSE 2 DOIS CONJUNTOS DE INFORMAÇÕES DIFERENTES.
# COMO O NÚMERO DE LINHAS DA PRIMEIRA PARTE É IGUAL AO NÚMERO DE LINHAS DA SEGUNDA, ISSO DEVE SER INTENCIONAL.
#
# TUDO INDICA QUE A PRIMEIRA PARTE CONTÉM DADOS DOS PEDIDOS DE EMENDAS E A SEGUNDA PARTE TEM OS DADOS DE EXECUÇÃO DAS MESMAS EMENDAS SOLICITADAS.
#
# O PANDAS PERMITE CARREGAR APENAS UMA PARTE DE UM ARQUIVO CSV, ENTÃO IREMOS CARREGAR A PRIMEIRA PARTE EM UM DATAFRAME E A SEGUNDA PARTE EM OUTRO DATAFRAME

# %%
# Importando as bibliotecas
import pandas as pd

# ATENÇÃO! VAMOS COMEÇAR FAZENDO APENAS JANEIRO E RESOLVENDO OS ERROS AOS POUCOS

# Usaremos o nrows para carregar apenas a primeira parte do arquivo

# Carregando o arquivo
# Somente a primeira parte, até onde está dando erro
df_janeiro_1 = pd.read_csv('emendasparlamentares-012017.csv', nrows=113)

df_janeiro_1.head()
# Out:
#         Parlamentar     Data Desbloqueio  Ano de Exercicio  \
# 0  CLÁUDIO ABRANTES  2017/01/20 00:00:00              2017
# 1  CLÁUDIO ABRANTES  2017/01/20 00:00:00              2017
# 2  CLÁUDIO ABRANTES  2017/01/20 00:00:00              2017
# 3  CLÁUDIO ABRANTES  2017/01/20 00:00:00              2017
# 4  CLÁUDIO ABRANTES  2017/01/20 00:00:00              2017
#
#    Unidade Orcamentaria Cod  \
# 0                     18101
# 1                     18101
# 2                     18101
# 3                     18101
# 4                     18101
#
#                            Unidade Orcamentaria Desc  \
# 0  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 1  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 2  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 3  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 4  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
#
#                                            SubTítulo  Código da Emenda  \
# 0  CONSTRUÇÃO DE PRÉDIOS E PRÓPRIOS-CONSTRUÇÃO DO...               466
# 1  DESCENTRALIZAÇÃO DE RECURSOS FINANCEIROS PARA ...               469
# 2  DESCENTRALIZAÇÃO DE RECURSOS FINANCEIROS PARA ...              5053
# 3  MODERNIZAÇÃO DE SISTEMA DE INFORMAÇÃO- INTERNE...               468
# 4  CONSTRUÇÃO DE UNIDADE DE ENSINO-CONTRUÇÃO DE U...               467
#
#    Nota Dotação  Ds Observação  Código Unidade Gestora  \
# 0           284            NaN                  160101
# 1           284            NaN                  160101
# 2           284            NaN                  160101
# 3           284            NaN                  160101
# 4           284            NaN                  160101
#
#   Código Programa Trabalho  Código Natureza Despesa  Vl Solicitado
# 0   12 .122.6002.1984.0005                   449051         300000
# 1   12 .122.6221.2387.0001                   335043         300000
# 2   12 .122.6221.2387.0055                   335043         300000
# 3   12 .126.6221.1471.0002                   339039         300000
# 4   12 .365.6221.5023.0004                   449051         300000

# %%
# Vamos verificar a quantidade de registros no arquivo
df_janeiro_1.count()
# Out:
# Parlamentar                  113
# Data Desbloqueio             113
# Ano de Exercicio             113
# Unidade Orcamentaria Cod     113
# Unidade Orcamentaria Desc    113
# SubTítulo                    113
# Código da Emenda             113
# Nota Dotação                 113
# Ds Observação                  0
# Código Unidade Gestora       113
# Código Programa Trabalho     113
# Código Natureza Despesa      113
# Vl Solicitado                113
# dtype: int64

# %%
# Agora vamos carregar o mesmo arquivo csv mas pulando as primeiras linhas, que já foram carregadas
# Usaremos o skiprows para isso
df_janeiro_2 = pd.read_csv('emendasparlamentares-012017.csv', skiprows=114)

df_janeiro_2.head()
# Out:
#         Parlamentar     Data Desbloqueio Mês/Ano Desbloqueio  \
# 0  CLÁUDIO ABRANTES  2017/01/20 00:00:00             01/2017
# 1  CLÁUDIO ABRANTES  2017/01/20 00:00:00             01/2017
# 2  CLÁUDIO ABRANTES  2017/01/20 00:00:00             01/2017
# 3  CLÁUDIO ABRANTES  2017/01/20 00:00:00             01/2017
# 4  CLÁUDIO ABRANTES  2017/01/20 00:00:00             01/2017
#
#    Ano de Exercicio  Unidade Orcamentaria Cod  \
# 0              2017                     18101
# 1              2017                     18101
# 2              2017                     18101
# 3              2017                     18101
# 4              2017                     18101
#
#                            Unidade Orcamentaria Desc  \
# 0  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 1  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 2  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 3  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 4  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
#
#                                            SubTítulo  Código da Emenda  \
# 0  CONSTRUÇÃO DE PRÉDIOS E PRÓPRIOS-CONSTRUÇÃO DO...               466
# 1  DESCENTRALIZAÇÃO DE RECURSOS FINANCEIROS PARA ...               469
# 2  DESCENTRALIZAÇÃO DE RECURSOS FINANCEIROS PARA ...              5053
# 3  MODERNIZAÇÃO DE SISTEMA DE INFORMAÇÃO- INTERNE...               468
# 4  CONSTRUÇÃO DE UNIDADE DE ENSINO-CONTRUÇÃO DE U...               467
#
#   Número Ofício  Nota Dotação       ...         Código Natureza Despesa  \
# 0           s/n           284       ...                          449051
# 1           s/n           284       ...                          335043
# 2           s/n           284       ...                          335043
# 3           s/n           284       ...                          339039
# 4           s/n           284       ...                          449051
#
#    Valor Alteração Valor Empenhado  Valor Bloqueado Valor Liquidado  \
# 0          -200000               0                0               0
# 1          -200000          500000                0          500000
# 2           200000               0           200000               0
# 3          -500000               0                0               0
# 4                0               0          1000000               0
#
#   Valor Disponível  Valor Lei Vl Desbloqueado Vl Solicitado  Valor da Emenda
# 0                0     200000          300000        300000         100000.0
# 1                0     700000          300000        300000              NaN
# 2                0          0          300000        300000              NaN
# 3                0     500000          300000        300000              NaN
# 4                0    1000000          300000        300000              NaN
#
# [5 rows x 23 columns]

# %%
# Verificando a qtde de registros
df_janeiro_2.count()
# Out:
# Parlamentar                  113
# Data Desbloqueio             113
# Mês/Ano Desbloqueio          113
# Ano de Exercicio             113
# Unidade Orcamentaria Cod     113
# Unidade Orcamentaria Desc    113
# SubTítulo                    113
# Código da Emenda             113
# Número Ofício                113
# Nota Dotação                 113
# Ds Observação                  0
# Código Unidade Gestora       113
# Código Programa Trabalho     113
# Código Natureza Despesa      113
# Valor Alteração              113
# Valor Empenhado              113
# Valor Bloqueado              113
# Valor Liquidado              113
# Valor Disponível             113
# Valor Lei                    113
# Vl Desbloqueado              113
# Vl Solicitado                113
# Valor da Emenda               10
# dtype: int64

# %%
# Exercício -> baixar fevereiro e importar

# Mesmo problema em fevereiro -> mesma solução
# A primeira parte
df_fevereiro_1 = pd.read_csv('emendasparlamentares-022017.csv', nrows=1558)

df_fevereiro_1.head()
# Out:
#     Parlamentar     Data Desbloqueio  Ano de Exercicio  \
# 0  AGACIEL MAIA  2017/02/22 00:00:00              2017
# 1  AGACIEL MAIA  2017/02/22 00:00:00              2017
# 2  AGACIEL MAIA  2017/02/22 00:00:00              2017
# 3  AGACIEL MAIA  2017/02/22 00:00:00              2017
# 4  AGACIEL MAIA  2017/02/22 00:00:00              2017
#
#    Unidade Orcamentaria Cod  \
# 0                     18101
# 1                     18101
# 2                     18101
# 3                     18101
# 4                     18101
#
#                            Unidade Orcamentaria Desc  \
# 0  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 1  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 2  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 3  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 4  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
#
#                                            SubTítulo  Código da Emenda  \
# 0  DESCENTRALIZAÇÃO DE RECURSOS FINANCEIROS PARA ...             11169
# 1  DESCENTRALIZAÇÃO DE RECURSOS FINANCEIROS PARA ...              4047
# 2  CONSTRUÇÃO DE QUADRAS DE ESPORTES-CONSTRUÇÃO D...               227
# 3  CONSTRUÇÃO DE QUADRAS DE ESPORTES-CONSTRUÇÃO D...               226
# 4  REFORMA DE UNIDADES DE ENSINO FUNDAMENTAL-PDAF...              2002
#
#    Nota Dotação Ds Observação  Código Unidade Gestora  \
# 0           271           NaN                  160101
# 1           271           NaN                  160101
# 2           271           NaN                  160101
# 3           271           NaN                  160101
# 4           271           NaN                  160101
#
#   Código Programa Trabalho  Código Natureza Despesa Vl Solicitado
# 0   12 .122.6221.2387.0024                   335043       2000000
# 1   12 .122.6221.2387.0032                   335043       2000000
# 2   12 .361.6221.1745.0003                   449051       2000000
# 3   12 .361.6221.1745.0004                   449051       2000000
# 4   12 .361.6221.3236.0014                   335043       4000000

# %%
df_fevereiro_1.count()
# Out:
# Parlamentar                  1558
# Data Desbloqueio             1558
# Ano de Exercicio             1558
# Unidade Orcamentaria Cod     1558
# Unidade Orcamentaria Desc    1558
# SubTítulo                    1558
# Código da Emenda             1558
# Nota Dotação                 1558
# Ds Observação                 228
# Código Unidade Gestora       1558
# Código Programa Trabalho     1558
# Código Natureza Despesa      1558
# Vl Solicitado                1558
# dtype: int64

# %%
# A segunda parte das emendas de fevereiro
df_fevereiro_2 = pd.read_csv('emendasparlamentares-022017.csv', skiprows=1559)

df_fevereiro_2.head()
# Out:
#     Parlamentar     Data Desbloqueio Mês/Ano Desbloqueio  Ano de Exercicio  \
# 0  AGACIEL MAIA  2017/02/22 00:00:00             02/2017              2017
# 1  AGACIEL MAIA  2017/02/22 00:00:00             02/2017              2017
# 2  AGACIEL MAIA  2017/02/22 00:00:00             02/2017              2017
# 3  AGACIEL MAIA  2017/02/22 00:00:00             02/2017              2017
# 4  AGACIEL MAIA  2017/02/22 00:00:00             02/2017              2017
#
#    Unidade Orcamentaria Cod  \
# 0                     18101
# 1                     18101
# 2                     18101
# 3                     18101
# 4                     18101
#
#                            Unidade Orcamentaria Desc  \
# 0  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 1  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 2  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 3  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
# 4  SECRETARIA DE ESTADO DE  EDUCAÇÃO DO DISTRITO ...
#
#                                            SubTítulo  Código da Emenda  \
# 0  DESCENTRALIZAÇÃO DE RECURSOS FINANCEIROS PARA ...             11169
# 1  DESCENTRALIZAÇÃO DE RECURSOS FINANCEIROS PARA ...              4047
# 2  CONSTRUÇÃO DE QUADRAS DE ESPORTES-CONSTRUÇÃO D...               227
# 3  CONSTRUÇÃO DE QUADRAS DE ESPORTES-CONSTRUÇÃO D...               226
# 4  REFORMA DE UNIDADES DE ENSINO FUNDAMENTAL-PDAF...              2002
#
#   Número Ofício  Nota Dotação       ...        Código Natureza Despesa  \
# 0       10/2017           271       ...                         335043
# 1       10/2017           271       ...                         335043
# 2       10/2017           271       ...                         449051
# 3       10/2017           271       ...                         449051
# 4       10/2017           271       ...                         335043
#
#    Valor Alteração Valor Empenhado  Valor Bloqueado Valor Liquidado  \
# 0            50000               0            50000               0
# 1           200000               0           200000               0
# 2          -200000               0                0               0
# 3                0               0           200000               0
# 4          2000000               0                0               0
#
#   Valor Disponível Valor Lei Vl Desbloqueado Vl Solicitado  Valor da Emenda
# 0                0         0         2000000       2000000              NaN
# 1                0         0         2000000       2000000              NaN
# 2                0    200000         2000000       2000000              NaN
# 3                0    200000         2000000       2000000              NaN
# 4          2000000         0         4000000       4000000              NaN
#
# [5 rows x 23 columns]

# %%
df_fevereiro_2.count()
# Out:
# Parlamentar                  1558
# Data Desbloqueio             1558
# Mês/Ano Desbloqueio          1558
# Ano de Exercicio             1558
# Unidade Orcamentaria Cod     1558
# Unidade Orcamentaria Desc    1558
# SubTítulo                    1558
# Código da Emenda             1558
# Número Ofício                1558
# Nota Dotação                 1558
# Ds Observação                 228
# Código Unidade Gestora       1558
# Código Programa Trabalho     1558
# Código Natureza Despesa      1558
# Valor Alteração              1558
# Valor Empenhado              1558
# Valor Bloqueado              1558
# Valor Liquidado              1558
# Valor Disponível             1558
# Valor Lei                    1558
# Vl Desbloqueado              1558
# Vl Solicitado                1558
# Valor da Emenda                64
# dtype: int64

# %%
# Podemos juntar DataFrames, colocando um no final do outro. Chamamos isso de Append
# Cuidado: colunas que só existem em 1 dataframe serão adicionadas ao novo DataFrame criado
# Outra possibilidade é usar a função Concat, que funciona de forma semelhante. Leia a documentação

# Iremos concatenar inicialmente a parte inicial dos dois arquivos
df_anterior = df_janeiro_1.append(df_fevereiro_1, ignore_index=True)

df_anterior.count()
# Out:
# Parlamentar                  1671
# Data Desbloqueio             1671
# Ano de Exercicio             1671
# Unidade Orcamentaria Cod     1671
# Unidade Orcamentaria Desc    1671
# SubTítulo                    1671
# Código da Emenda             1671
# Nota Dotação                 1671
# Ds Observação                 228
# Código Unidade Gestora       1671
# Código Programa Trabalho     1671
# Código Natureza Despesa      1671
# Vl Solicitado                1671
# dtype: int64

# %%
# Fazer a mesma coisa para os outros 2 DataFrames que correspondem aos dados da parte final dos dois arquivos
df_posterior = df_janeiro_2.append(df_fevereiro_2, ignore_index=True)

df_posterior.count()
# Out:
# Parlamentar                  1671
# Data Desbloqueio             1671
# Mês/Ano Desbloqueio          1671
# Ano de Exercicio             1671
# Unidade Orcamentaria Cod     1671
# Unidade Orcamentaria Desc    1671
# SubTítulo                    1671
# Código da Emenda             1671
# Número Ofício                1671
# Nota Dotação                 1671
# Ds Observação                 228
# Código Unidade Gestora       1671
# Código Programa Trabalho     1671
# Código Natureza Despesa      1671
# Valor Alteração              1671
# Valor Empenhado              1671
# Valor Bloqueado              1671
# Valor Liquidado              1671
# Valor Disponível             1671
# Valor Lei                    1671
# Vl Desbloqueado              1671
# Vl Solicitado                1671
# Valor da Emenda                74
# dtype: int64

# %%
# Exercício
# Baixar todos os arquivos de 2017, carregar cada mês em 2 DataFrames distintos
# E concatenar todos os DataFrames da primeira e todos os DataFrames da segunda
# Assim teremos todas as solicitações de emendas parlamentares de 2017 em um DataFrame
# E todas as execuções de emendas de 2017 em outro DataFrame
