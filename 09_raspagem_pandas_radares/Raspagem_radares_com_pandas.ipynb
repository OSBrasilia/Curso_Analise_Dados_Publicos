# %% [markdown]
# # Análise dos radares do DF
# Com base nos dados sobre cada radar, de cada tipo, disponível no site do Detran/DF vamos tentar obter informações sobre eles
#
# Existem bibliotecas específicas para auxiliar a raspagem de dados, mas o próprio pandas conseguem obter dados de sites, desde que os dados estejam em tabelas.

# %%
# Importando as bibliotecas
import requests
import pandas as pd

# Site onde estão os dados
url = "http://getran.detran.df.gov.br/site/veiculos/listar-radares.jsp"

# Requisicao para obter os dados
r = requests.get(url)

# Obtém os dados do HTML da página
table = pd.read_html(r.text)

# Pega o primeiro elemento, a tabela
df = table[0]

df.head()
# Out:
#    Código                                     Local  \
# 0  DTR033  AV GOIAS N100 PLANALT(SENT CENT/CH M.D'A
# 1  DTR032  AV GOIAS Q2 PLANALT(SENT CH M D'A/CENTR)
# 2  DTR182              W4 HCGN 715 (SENT SUL/NORTE)
# 3  DTR179           EIXO W SQN 106 (SENT SUL/NORTE)
# 4  DTR178           EIXO W SQN 106 (SENT NORTE/SUL)
#
#                           Tipo Classificação da Via
# 0  RADAR (BARREIRA ELETRONICA)                  NaN
# 1  RADAR (BARREIRA ELETRONICA)                  NaN
# 2  RADAR (BARREIRA ELETRONICA)                  NaN
# 3  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 4  RADAR (BARREIRA ELETRONICA)             ARTERIAL

# %%
# Quantos radares existem em Brasília?
df.count()
# Out:
# Código                  739
# Local                   739
# Tipo                    739
# Classificação da Via    626
# dtype: int64

# %%
# Convertendo todos os locais para maiúscula
df.Local = df.Local.str.upper()

# %%
print(df)
# Out:
#      Código                                              Local  \
# 0    DTR033           AV GOIAS N100 PLANALT(SENT CENT/CH M.D'A
# 1    DTR032           AV GOIAS Q2 PLANALT(SENT CH M D'A/CENTR)
# 2    DTR182                       W4 HCGN 715 (SENT SUL/NORTE)
# 3    DTR179                    EIXO W SQN 106 (SENT SUL/NORTE)
# 4    DTR178                    EIXO W SQN 106 (SENT NORTE/SUL)
# 5    DTR171                    EIXO W SQS 103 (SENT SUL/NORTE)
# 6    DTR170                    EIXO W SQS 103 (SENT NORTE/SUL)
# 7    DTR165  L4 NORTE PROX FUZILEIROS NAVAISSENT UNB/VILA P...
# 8    DTR164  L4 NORTE PROX FUZILEIROS NAVAISSENT VILA PLANA...
# 9    DTR021                     L2 SQN 410 ( SENT. NORTE/SUL )
# 10   DTR020                    L2 SGAN 611 ( SENT. SUL/NORTE )
# 11   DTR002                    EPIG PROX PARQUE (SENT SIG/SIA)
# 12   DTR001                    EPIG PROX PARQUE (SENT SIA/SIG)
# 13   ASV097  W3 SUL ALT. SHIGS 708/709 SENT. NORTE/SUL SEMA...
# 14   ASV096  W3 SUL ALT. SCRS 508/509 SENT. SUL/NORTE SEMAF...
# 15   ASV095  AV SANDU NORTE TAG QNE 25/34 SENT. SUL/NORTE S...
# 16   ASV094  AV COM NORTE TAG CNB 06/07 SENT. NORTE/SUL SEM...
# 17   ASV093  AV COM NORTE TAG QNE 17/26 SENT. NORTE/SUL SEM...
# 18   ASV092  AV COM NORTE TAG QND 27/28 SENT. SUL/NORTE SEM...
# 19   ASV091  AV SANDU NORTE TAG QNC 06 SENT. NORTE/SUL SEMA...
# 20   ASV090  AV COM NORTE TAG QNA 54/QND01 SENT. SUL/NORTE ...
# 21   ASV108  L4 SUL ALT. ACAMP. TELEBRASILIA SENT NORTE/SUL...
# 22   ASV107  L4 SUL ALT. ACAMP. TELEBRASILIA SENT SUL/NORTE...
# 23   ASV099  AV. PIONEIROS ALT. Q5 GAMA SENT SETOR OESTE/SA...
# 24   ASV098  AV. PIONEIROS ALT. Q34/36 GAMA SENT SANTA MARI...
# 25   ASV087     VIA N1 ALT. TRIBUNAL CONTAS SENT. ESPLAN/RODOF
# 26   ASV086   VIA N1 ALT. CENTRO CONVENCOES SENT. ESPLAN/RODOF
# 27   ASV085  VIA N1 RODOV RETORNO S1/N1 ALT TEATRO NAC SENT...
# 28   ASV084  VIA S1 RODOV RETORNO N1/S1 ALT SDS SENT W3/L2 ...
# 29   ASV083                VIA S1 ALT. TJDF SENT. RODOF/ESPLAN
# ..      ...                                                ...
# 709  RFM156              AV CONTORNO QE 21 GUARA II (SENT N/S)
# 710  RFM157              AV CONTORNO QE 19 GUARA II (SENT S/N)
# 711  RFM104   AV ALAGADOS CL 107 SANTA MARIA (SENT BR040/GAMA)
# 712  RFM186            VIA ST POL SUL FTE ANA (SENT EIXO/CRUZ)
# 713  RFM234                L2 NORTE ALT SQN 411 SENT NORTE/SUL
# 714  RFM235               L2 NORTE ALT SGAN 611 SENT SUL/NORTE
# 715  RFM214     VIA M1 CEILANDIA QNM 11SENT ELMO SEREJO/CENTRO
# 716  RFM045              L4 SUL FRT AO S.L.U. (SENT SUL/NORTE)
# 717  RFM034           VIA LIG W3-L4 N PROX P BRAG (SENT L4/W3)
# 718  RFM032           AV GOIAS Q2 PLANALT(SENT CH M D'A/CENTR)
# 719  RFM227  EPAA 400M ANTES DO CAMPING DE BRASILIA SENT EP...
# 720  RFM236  VIA TERMINAL NORTE 320M ANTES DO 2:CBM SENT DF...
# 721  RFM237  VIA TERMINAL NORTE 420M ANTES DA DF-003(EPIA) ...
# 722  RFM218  VIA MN2 CEIL QNN 07 CONJ A FRENTE LT 14 SENT S...
# 723  RFM219  VIA MN2 CEIL QNM 08 CONJ A FRENTE LT 21 SENT C...
# 724  RFM238               L4 SUL FRENTE A ASBAC SENT NORTE/SUL
# 725  RFM239               L4 SUL FRENTE A ASBAC SENT SUL/NORTE
# 726  RFM183                       W5 SGAN 904 (SENT NORTE/SUL)
# 727  RFM240      W4 NORTE HCGN 704 PROX BLOCO I SENT SUL/NORTE
# 728  RFM064           AV PION. Q42 ST LESTE GAMA SENT GAMA/BSB
# 729  RFM065           AV PION Q3 ST SUL GAMA SENT GAMA/STA MAR
# 730  RFM072           VIA N3 QNN 32 CEIL(SENT SET O/ E.SEREJO)
# 731  RFM073           VIA N3 QNN 24 CEIL(SENT E. SEREJO/SET O)
# 732  RFM221  VIA LW1 BRAZLANDIA PROX CH 1A SULSETOR TRAD SE...
# 733  RFM203           VIA S1 E.MONUM CRUZ VELHO(SENT RODO/CONG
# 734  RFM033           AV GOIAS N100 PLANALT(SENT CENT/CH M.D'A
# 735  RFM132                    EIXO L SQN 210 (SENT NORTE/SUL)
# 736  RFM170                    EIXO W SQS 103 (SENT NORTE/SUL)
# 737  RFM171                    EIXO W SQS 103 (SENT SUL/NORTE)
# 738  RFM152  AV. CONTORNO GUARA II QE 24 PROXIMO A ESTACAO ...
#
#                             Tipo Classificação da Via
# 0    RADAR (BARREIRA ELETRONICA)                  NaN
# 1    RADAR (BARREIRA ELETRONICA)                  NaN
# 2    RADAR (BARREIRA ELETRONICA)                  NaN
# 3    RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 4    RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 5    RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 6    RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 7    RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 8    RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 9    RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 10   RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 11   RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 12   RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 13               AVANCO DE SINAL             ARTERIAL
# 14               AVANCO DE SINAL             ARTERIAL
# 15               AVANCO DE SINAL             ARTERIAL
# 16               AVANCO DE SINAL             ARTERIAL
# 17               AVANCO DE SINAL             ARTERIAL
# 18               AVANCO DE SINAL             ARTERIAL
# 19               AVANCO DE SINAL             ARTERIAL
# 20               AVANCO DE SINAL             ARTERIAL
# 21               AVANCO DE SINAL             ARTERIAL
# 22               AVANCO DE SINAL             ARTERIAL
# 23               AVANCO DE SINAL             ARTERIAL
# 24               AVANCO DE SINAL             ARTERIAL
# 25               AVANCO DE SINAL             ARTERIAL
# 26               AVANCO DE SINAL             ARTERIAL
# 27               AVANCO DE SINAL             ARTERIAL
# 28               AVANCO DE SINAL             ARTERIAL
# 29               AVANCO DE SINAL             ARTERIAL
# ..                           ...                  ...
# 709  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 710  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 711  RADAR (BARREIRA ELETRONICA)             COLETORA
# 712  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 713  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 714  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 715  RADAR (BARREIRA ELETRONICA)             COLETORA
# 716  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 717  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 718  RADAR (BARREIRA ELETRONICA)                  NaN
# 719  RADAR (BARREIRA ELETRONICA)             COLETORA
# 720  RADAR (BARREIRA ELETRONICA)             COLETORA
# 721  RADAR (BARREIRA ELETRONICA)             COLETORA
# 722  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 723  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 724  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 725  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 726  RADAR (BARREIRA ELETRONICA)                  NaN
# 727  RADAR (BARREIRA ELETRONICA)             COLETORA
# 728  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 729  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 730  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 731  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 732  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 733  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 734  RADAR (BARREIRA ELETRONICA)                  NaN
# 735  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 736  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 737  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 738  RADAR (BARREIRA ELETRONICA)             ARTERIAL
#
# [739 rows x 4 columns]

# %%
# Exercício: Quantos radares de cada tipo

# Resposta 1: Contar os valores do campo
df.Tipo.value_counts()
# Out:
# RADAR (BARREIRA ELETRONICA)    477
# AVANCO DE SINAL                132
# LOMBADA                        104
# RADAR MOVEL                     21
# CRONOMETRO                       5
# Name: Tipo, dtype: int64

# %%
# Resposta 2: Agrupar por Tipo
df.groupby('Tipo').count()
# Out:
#                              Código  Local  Classificação da Via
# Tipo
# AVANCO DE SINAL                 132    132                   131
# CRONOMETRO                        5      5                     5
# LOMBADA                         104    104                    71
# RADAR (BARREIRA ELETRONICA)     477    477                   398
# RADAR MOVEL                      21     21                    21

# %%
# Exercício: Quantos radares existem na via L2? Por cada Tipo!

# Solucão 1 : Criar novo dataframe filtrando por L2
df_radaresL2 = df[df.Local.str.contains('L2')]

df_radaresL2.count()
# Out:
# Código                  48
# Local                   48
# Tipo                    48
# Classificação da Via    46
# dtype: int64

# %%
df_radaresL2.groupby('Tipo').count()
# Out:
#                              Código  Local  Classificação da Via
# Tipo
# AVANCO DE SINAL                  23     23                    23
# LOMBADA                           6      6                     6
# RADAR (BARREIRA ELETRONICA)      19     19                    17

# %%
# Vamos ver se está certo?
df_radaresL2
# Out:
#      Código                                              Local  \
# 9    DTR021                     L2 SQN 410 ( SENT. NORTE/SUL )
# 10   DTR020                    L2 SGAN 611 ( SENT. SUL/NORTE )
# 27   ASV085  VIA N1 RODOV RETORNO S1/N1 ALT TEATRO NAC SENT...
# 28   ASV084  VIA S1 RODOV RETORNO N1/S1 ALT SDS SENT W3/L2 ...
# 30   ASV082  VIA S1 ALT CRUZ S1/L2 SUL SENT ROD/ESPLA SEMAF...
# 31   ASV081  VIA S1 ALT CRUZ S1/L2 SUL SENT ROD/ESPLA SEMAF...
# 41   ASV029  L2 NORTE ALT SGAN 605 SENT SUL/NORTE SEMAFORO ...
# 42   ASV026  L2 SUL SAS ALT QD 06 SENT NORTE/SUL SEMAFORO C...
# 50   ASV028  L2 NORTE ALT SQN 406 SENT NORTE/SUL SEMAFORO C...
# 51   ASV027  VIA S3 SBS ALT QD 04 SENT SBS/L2 SUL SEMAFORO ...
# 74   ASV002   L2 SUL SGAS 608 SENT SUL/NORTE SEMAFORO CRUZ 093
# 75   ASV001    L2 SUL SQS 408 SENT NORTE/SUL SEMAFORO CRUZ 092
# 76   ASV042  L2 NORTE SQN 401 SENT NORTE/SUL SEMAFORO CRUZ 198
# 82   ASV071               VIA S3 SCS ALT. QD 01SENT. L2/W3 SUL
# 84   ASV069                         VIA S3 SBS SENT. L2/W3 SUL
# 85   ASV068                L2 SUL PROX. QD 601 SENT. SUL/NORTE
# 100  ASV053                    L2 SUL SGAS 604 SENT. SUL/NORTE
# 101  ASV052                     L2 SUL SQS 404 SENT. NORTE/SUL
# 111  ASV101  L4 NORTE COM FINAL DA L2 NORTE SENT. L4/SETOR ...
# 115  ASV048   VIA S3 SMHS 301 SENT W3/L2 SUL SEMAFORO CRUZ 023
# 116  ASV047   L2 SUL SGAS 612 SENT SUL/NORTE SEMAFORO CRUZ 099
# 117  ASV046    L2 SUL SQS 412 SENT NORTE/SUL SEMAFORO CRUZ 099
# 150  DTR235               L2 NORTE ALT SGAN 611 SENT SUL/NORTE
# 151  DTR234                L2 NORTE ALT SQN 411 SENT NORTE/SUL
# 177  DTR189           L2 SGAS615 PROX COR JESUS(SENT SUL/NORTE
# 178  DTR188                        L2 SQS 415 (SENT NORTE/SUL)
# 267  RDD188                        L2 SQS 415 (SENT NORTE/SUL)
# 281  BEV08W            L SUL QI 6/8 ALT P. DAS GARGAS SENT. L2
# 315  BEV225            L2 SUL ALTURA CASA DO CANDANGO BRASILIA
# 337  BEV226            L2 SUL ALTURA CASA DO CANDANGO BRASILIA
# 361  LRE226            L2 SUL ALTURA CASA DO CANDANGO BRASILIA
# 362  LRE225            L2 SUL ALTURA CASA DO CANDANGO BRASILIA
# 366  ASV037  VIA N1 RODOV RETORNO S1/N1 ALT TEATRO NAC SENT...
# 367  ASV036  VIA S1 RODOV RETORNO N1/S1 ALT SDS SENT W3/L2 ...
# 378  RDD025                     L2 SQN 416 ( SENT. NORTE/SUL )
# 379  RDD024                    L2 SGAN 615 ( SENT. SUL/NORTE )
# 384  RDD189           L2 SGAS615 PROX COR JESUS(SENT SUL/NORTE
# 403  RDD021                     L2 SQN 410 ( SENT. NORTE/SUL )
# 404  RDD020                    L2 SGAN 611 ( SENT. SUL/NORTE )
# 447  RFD234                L2 NORTE ALT SQN 411 SENT NORTE/SUL
# 448  RFD235               L2 NORTE ALT SGAN 611 SENT SUL/NORTE
# 509  RFD249  VIA DE LIG L2-PONTE COSTA E SILVA A 70MDO VIAD...
# 527  BDT009  VIA DE LIG L2-PONTE COSTA E SILVA SENT P. PILO...
# 539  RIS101  L4 NORTE COM FINAL DA L2 NORTE SENT. L4/SETOR ...
# 624  RFM188                        L2 SQS 415 (SENT NORTE/SUL)
# 625  RFM189           L2 SGAS615 PROX COR JESUS(SENT SUL/NORTE
# 713  RFM234                L2 NORTE ALT SQN 411 SENT NORTE/SUL
# 714  RFM235               L2 NORTE ALT SGAN 611 SENT SUL/NORTE
#
#                             Tipo Classificação da Via
# 9    RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 10   RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 27               AVANCO DE SINAL             ARTERIAL
# 28               AVANCO DE SINAL             ARTERIAL
# 30               AVANCO DE SINAL             ARTERIAL
# 31               AVANCO DE SINAL             ARTERIAL
# 41               AVANCO DE SINAL             ARTERIAL
# 42               AVANCO DE SINAL             ARTERIAL
# 50               AVANCO DE SINAL             ARTERIAL
# 51               AVANCO DE SINAL             COLETORA
# 74               AVANCO DE SINAL             ARTERIAL
# 75               AVANCO DE SINAL             ARTERIAL
# 76               AVANCO DE SINAL             ARTERIAL
# 82               AVANCO DE SINAL             COLETORA
# 84               AVANCO DE SINAL             COLETORA
# 85               AVANCO DE SINAL             ARTERIAL
# 100              AVANCO DE SINAL             ARTERIAL
# 101              AVANCO DE SINAL             ARTERIAL
# 111              AVANCO DE SINAL             ARTERIAL
# 115              AVANCO DE SINAL             COLETORA
# 116              AVANCO DE SINAL             ARTERIAL
# 117              AVANCO DE SINAL             ARTERIAL
# 150  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 151  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 177  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 178  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 267  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 281                      LOMBADA             ARTERIAL
# 315                      LOMBADA             ARTERIAL
# 337                      LOMBADA             ARTERIAL
# 361                      LOMBADA             ARTERIAL
# 362                      LOMBADA             ARTERIAL
# 366              AVANCO DE SINAL             ARTERIAL
# 367              AVANCO DE SINAL             ARTERIAL
# 378  RADAR (BARREIRA ELETRONICA)                  NaN
# 379  RADAR (BARREIRA ELETRONICA)                  NaN
# 384  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 403  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 404  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 447  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 448  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 509  RADAR (BARREIRA ELETRONICA)             COLETORA
# 527                      LOMBADA             COLETORA
# 539              AVANCO DE SINAL             ARTERIAL
# 624  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 625  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 713  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 714  RADAR (BARREIRA ELETRONICA)             ARTERIAL

# %%
# Separar apenas os radares da L2 Norte
df_radaresL2Norte = df_radaresL2[df_radaresL2.Local.str.contains('L2 NORTE')]

df_radaresL2Norte
# Out:
#      Código                                              Local  \
# 41   ASV029  L2 NORTE ALT SGAN 605 SENT SUL/NORTE SEMAFORO ...
# 50   ASV028  L2 NORTE ALT SQN 406 SENT NORTE/SUL SEMAFORO C...
# 76   ASV042  L2 NORTE SQN 401 SENT NORTE/SUL SEMAFORO CRUZ 198
# 111  ASV101  L4 NORTE COM FINAL DA L2 NORTE SENT. L4/SETOR ...
# 150  DTR235               L2 NORTE ALT SGAN 611 SENT SUL/NORTE
# 151  DTR234                L2 NORTE ALT SQN 411 SENT NORTE/SUL
# 447  RFD234                L2 NORTE ALT SQN 411 SENT NORTE/SUL
# 448  RFD235               L2 NORTE ALT SGAN 611 SENT SUL/NORTE
# 539  RIS101  L4 NORTE COM FINAL DA L2 NORTE SENT. L4/SETOR ...
# 713  RFM234                L2 NORTE ALT SQN 411 SENT NORTE/SUL
# 714  RFM235               L2 NORTE ALT SGAN 611 SENT SUL/NORTE
#
#                             Tipo Classificação da Via
# 41               AVANCO DE SINAL             ARTERIAL
# 50               AVANCO DE SINAL             ARTERIAL
# 76               AVANCO DE SINAL             ARTERIAL
# 111              AVANCO DE SINAL             ARTERIAL
# 150  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 151  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 447  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 448  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 539              AVANCO DE SINAL             ARTERIAL
# 713  RADAR (BARREIRA ELETRONICA)             ARTERIAL
# 714  RADAR (BARREIRA ELETRONICA)             ARTERIAL
